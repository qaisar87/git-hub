# %% [markdown]
# # Import libraries
# -searborn

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
phool = sns.load_dataset("iris")
phool
# draw a line plot
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       7 # draw a line plot
#       8 sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
# ----> 9 plot.show()
#
# NameError: name 'plot' is not defined

# %% [markdown]
# ## adding titles

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
phool = sns.load_dataset("iris")
phool
# draw a line plot
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plt.title("phoolon ka har")

plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       8 sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
#       9 plt.title("phoolon ka har")
# ---> 11 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Add limits

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
phool = sns.load_dataset("iris")
phool
# draw a line plot
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plt.title("phoolon ka har")
plt.xlim(2)
plt.ylim(1)


plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 14
#      10 plt.xlim(2)
#      11 plt.ylim(1)
# ---> 14 plot.show()
#
# NameError: name 'plot' is not defined

# %% [markdown]
# # Set Styles
# . darkgrid
# .whitegrid
# .dark
# .whte
# .ticks

# %%
set_style(style=None, rc=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 set_style(style=None, rc=None)
#
# NameError: name 'set_style' is not defined

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None, rc=None)
# load dataset
phool = sns.load_dataset("iris")
phool
# draw a line plot
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plt.title("phoolon ka har")
sns.set_style("dark")


plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 14
#      10 plt.title("phoolon ka har")
#      11 sns.set_style("dark")
# ---> 14 plot.show()
#
# NameError: name 'plot' is not defined

# %% [markdown]
# # Size of figure

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
phool = sns.load_dataset("iris")
# change figure
plt.figure(figsize=(8,6))
# draw a line plot
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plt.title("phoolon ka har")
sns.set_style("dark")


plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 14
#      10 plt.title("phoolon ka har")
#      11 sns.set_style("dark")
# ---> 14 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
phool = sns.load_dataset("iris")
phool

# draw a line plot
sns.barplot(x="species", y= "petal_length", data=phool)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 10
#       8 # draw a line plot
#       9 sns.barplot(x="species", y= "petal_length", data=phool)
# ---> 10 plot.show()
#
# NameError: name 'plot' is not defined

# %%
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="who", y= "alone", hue= "who", data=kashti)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 10
#       8 # draw a line plot
#       9 sns.barplot(x="who", y= "alone", hue= "who", data=kashti)
# ---> 10 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="who", y= "alone", hue= "who", data=kashti, order=["female", "male"])
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 10
#       8 # draw a line plot
#       9 sns.barplot(x="who", y= "alone", hue= "who", data=kashti, order=["female", "male"])
# ---> 10 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"])
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 10
#       8 # draw a line plot
#       9 sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"])
# ---> 10 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"], color="red")
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 10
#       8 # draw a line plot
#       9 sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"], color="red")
# ---> 10 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"], color="red", ci= None)
plot.show()
# Out:
# C:\Users\qaisarsa\AppData\Local\Temp\ipykernel_28140\1460880152.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"], color="red", ci= None)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 10
#       8 # draw a line plot
#       9 sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"], color="red", ci= None)
# ---> 10 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"], color="red", ci= None,palette='pastel' )
plot.show()
# Out:
# C:\Users\qaisarsa\AppData\Local\Temp\ipykernel_28140\3031567465.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"], color="red", ci= None,palette='pastel' )
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 10
#       8 # draw a line plot
#       9 sns.barplot(x="sex", y= "alone", hue= "who", data=kashti, order=["female", "male"], color="red", ci= None,palette='pastel' )
# ---> 10 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
from numpy import median
import matplotlib.pyplot as plt

# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="class", y= "fare", hue= "sex", data=kashti, estimator=median )
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 12
#      10 # draw a line plot
#      11 sns.barplot(x="class", y= "fare", hue= "sex", data=kashti, estimator=median )
# ---> 12 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
from numpy import median
import matplotlib.pyplot as plt

# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="class", y= "fare", hue= "sex", data=kashti, estimator=median, saturation=0.2)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 12
#      10 # draw a line plot
#      11 sns.barplot(x="class", y= "fare", hue= "sex", data=kashti, estimator=median, saturation=0.2)
# ---> 12 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
from numpy import median
import matplotlib.pyplot as plt

# load dataset
kashti = sns.load_dataset("titanic")
kashti

# draw a line plot
sns.barplot(x="fare", y= "class", hue= "sex", data=kashti, estimator=median, saturation=1)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 12
#      10 # draw a line plot
#      11 sns.barplot(x="fare", y= "class", hue= "sex", data=kashti, estimator=median, saturation=1)
# ---> 12 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
#read a titanic.csv file
#from seaborn library
# load dataset
kashti = sns.load_dataset('titanic')
kashti

sns.barplot(x="class", y= "fare", data=kashti, 
                linewidth=3, facecolor=(1,1,1,0),
                 edgecolor="0")
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a simple plot
plt.figure(figsize=(6, 4))
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro-')
plt.title('Graphical Abstract Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Save the graphical abstract as an image
plt.savefig('graphical_abstract.png', dpi=300, bbox_inches='tight')

# Show the graphical abstract
plt.show()
