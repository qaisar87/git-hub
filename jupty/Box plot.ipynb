# %%
# Import libraries
import seaborn
import matplotlib.pyplot as plt
#canvas (Baloon board)
seaborn.set(style='whitegrid')
# load dataset
kashti = sns.load_dataset("titanic")
kashti

seaborn.boxplot(x="class", y= "fare", data=kashti)
plt.show()

# %%
# Import libraries
import seaborn as sns
import pandas as pf
import numpy as np

# load dataset
tip = sns.load_dataset("tips")
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Import libraries
import seaborn as sns
# use to set style of background of plot
seaborn.set(style="whitegrid")
tip = sns.load_dataset("tips")
seaborn.boxplot(y=tip["size"])
# Out:
# <Axes: ylabel='size'>

# %%
# Import libraries
import seaborn as sns
# use to set style of background of plot
seaborn.set(style="whitegrid")
tip = sns.load_dataset("tips")
sns.boxplot(x="tip",y="day", hue="smoker", data=tip, color="#34c9eb",)
# how to manage individual colors for each hue color
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
# Import libraries
import seaborn as sns
import pandas as pf
import numpy as np
import matplotlib.pyplot as plt

kashti = sns.load_dataset("titanic")
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Import libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

kashti = sns.load_dataset("titanic")


sns.boxplot(x="survived", y="age", showmeans=True, meanprops={"marker":"*","markersize":"12","markeredgecolor":"red"}, data=kashti)

plt.xlabel("How many survived"),
plt.ylabel("Age(years)"),
plt.title ("Box plot of")
plt.show()

# %%
sns.boxplot(x="survived", y="age", data=kashti)
plt.show()

# %%
import seaborn as sns
import pandas as pf
import numpy as np
import matplotlib.pyplot as plt

kashti = sns.load_dataset("titanic")
kashti
sns.boxplot(x=="survived", y=="age", showmeans==True, meanproops=={"marker":"*","markersize":12,"markeredgecolor":"red"}, data==kashti)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 8
#       6 kashti = sns.load_dataset("titanic")
#       7 kashti
# ----> 8 sns.boxplot(x=="survived", y=="age", showmeans==True, meanproops=={"marker":"*","markersize":12,"markeredgecolor":"red"}, data==kashti)
#       9 plt.show()
#
# NameError: name 'x' is not defined

# %%
c
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
# Import libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

kashti = sns.load_dataset("titanic")


sns.boxplot(x="survived", y="age", showmeans=True, meanprops={"marker": "*", "markersize": "12", "markeredgecolor": "red"}, data=kashti)  

plt.xlabel("How many survived")
plt.ylabel("Age (years)")
plt.title("Box plot of Age Distribution by Survival")
plt.show()

# %%
# Import libraries
import seaborn as sns
import pandas as pf
import numpy as np
import matplotlib.pyplot as plt

kashti = sns.load_dataset("titanic")
kashti

sns.boxplot(x="survived", y="age", showmeans=True, 'meanproops'= {"marker":"*","markersize":"12","markeredgecolor":"red"}, data=kashti),
plt.xlabel("How many survived"),
plt.ylabel("Age(years)"),
plt.title ("Box plot of")
plt.show ()
# Out:
#   Cell In[103], line 10
#     sns.boxplot(x="survived", y="age", showmeans=True, 'meanproops'= {"marker":"*","markersize":"12","markeredgecolor":"red"}, data=kashti),
#                                                        ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
